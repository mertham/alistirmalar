# %%
#3 rakamlı cift sayilar arasinda en az iki rakami ayni olan sayilar 
for a in range(1,10):
    for b in range(0,10):
        for c in range(0,10,2):
            if(a!=b!=c):
                continue
            print(a,b,c)
# Out:
# 1 0 0
# 1 1 0
# 1 1 2
# 1 1 4
# 1 1 6
# 1 1 8
# 1 2 2
# 1 4 4
# 1 6 6
# 1 8 8
# 2 0 0
# 2 2 0
# 2 2 2
# 2 2 4
# 2 2 6
# 2 2 8
# 2 4 4
# 2 6 6
# 2 8 8
# 3 0 0
# 3 2 2
# 3 3 0
# 3 3 2
# 3 3 4
# 3 3 6
# 3 3 8
# 3 4 4
# 3 6 6
# 3 8 8
# 4 0 0
# 4 2 2
# 4 4 0
# 4 4 2
# 4 4 4
# 4 4 6
# 4 4 8
# 4 6 6
# 4 8 8
# 5 0 0
# 5 2 2
# 5 4 4
# 5 5 0
# 5 5 2
# 5 5 4
# 5 5 6
# 5 5 8
# 5 6 6
# 5 8 8
# 6 0 0
# 6 2 2
# 6 4 4
# 6 6 0
# 6 6 2
# 6 6 4
# 6 6 6
# 6 6 8
# 6 8 8
# 7 0 0
# 7 2 2
# 7 4 4
# 7 6 6
# 7 7 0
# 7 7 2
# 7 7 4
# 7 7 6
# 7 7 8
# 7 8 8
# 8 0 0
# 8 2 2
# 8 4 4
# 8 6 6
# 8 8 0
# 8 8 2
# 8 8 4
# 8 8 6
# 8 8 8
# 9 0 0
# 9 2 2
# 9 4 4
# 9 6 6
# 9 8 8
# 9 9 0
# 9 9 2
# 9 9 4
# 9 9 6
# 9 9 8
